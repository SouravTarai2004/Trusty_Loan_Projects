# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Reading Dataset

# %%
dataset = pd.read_csv("updated_loan_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataset = pd.read_csv("C:\\Users\\soura\\Desktop\\heart.csv")
#
# NameError: name 'pd' is not defined

# %%
dataset.head()
# Out:
#    person_age person_gender person_education  person_annual_income  \
# 0          22        female           Master              611558.0
# 1          21        female      High School              104397.0
# 2          25        female      High School              105723.0
# 3          23        female         Bachelor              677900.5
# 4          24          male           Master              562147.5
#
#    person_emp_exp person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0               0                  RENT     385000    PERSONAL          16.02
# 1               0                   OWN      11000   EDUCATION          11.14
# 2               3              MORTGAGE      60500     MEDICAL          12.87
# 3               0                  RENT     385000     MEDICAL          15.23
# 4               1                  RENT     385000     MEDICAL          14.27
#
#    person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                        3           561                             No
# 1                        2           504                            Yes
# 2                        3           635                             No
# 3                        2           675                             No
# 4                        4           586                             No
#
#    loan_status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
dataset.describe()
# Out:
#          person_age  person_annual_income  person_emp_exp      loan_amnt  \
# count  45000.000000          4.500000e+04    45000.000000   45000.000000
# mean      27.764178          6.827120e+05        5.410333  105414.733111
# std        6.045108          6.835912e+05        6.063532   69463.753596
# min       20.000000          6.800000e+04        0.000000    5500.000000
# 25%       24.000000          4.012340e+05        1.000000   55000.000000
# 50%       26.000000          5.699080e+05        4.000000   88000.000000
# 75%       30.000000          8.142086e+05        8.000000  134609.750000
# max      144.000000          6.120651e+07      125.000000  385000.000000
#
#        loan_int_rate  person_cred_hist_length  credit_score   loan_status
# count   45000.000000             45000.000000  45000.000000  45000.000000
# mean       11.006606                 5.867489    632.608756      0.222222
# std         2.978808                 3.879702     50.435865      0.415744
# min         5.420000                 2.000000    390.000000      0.000000
# 25%         8.590000                 3.000000    601.000000      0.000000
# 50%        11.010000                 4.000000    640.000000      0.000000
# 75%        12.990000                 8.000000    670.000000      0.000000
# max        20.000000                30.000000    850.000000      1.000000

# %%
dataset.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_annual_income              0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# person_cred_hist_length           0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  int64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_annual_income            45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  int64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   person_cred_hist_length         45000 non-null  int64
#  10  credit_score                    45000 non-null  int64
#  11  previous_loan_defaults_on_file  45000 non-null  object
#  12  loan_status                     45000 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 4.5+ MB

# %%
categorical_features = dataset.select_dtypes(include="object").columns
# categorical_features means are variables that represent discrete categories rather than continuous numerical values. eg- "color"-blue,red,  "city"-patna, baharagora
# dtypes means are datatypes of columns in a dataset(like in pandas or numpy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 categorical_features = dataset.select_datatypes(include="object").columns
#
# NameError: name 'dataset' is not defined

# %%
categorical_features
# Out:
# Index(['person_gender', 'person_education', 'person_home_ownership',
#        'loan_intent', 'previous_loan_defaults_on_file'],
#       dtype='object')

# %%
numerical_features = dataset.select_dtypes(include="number").columns
#  numerical features in a dataset, we mean the columns that contain numbers (integers or floats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numerical_features = dataset.select_dtypes(include="number").columns
#
# NameError: name 'dataset' is not defined

# %%
numerical_features
# Out:
# Index(['person_age', 'person_annual_income', 'person_emp_exp', 'loan_amnt',
#        'loan_int_rate', 'person_cred_hist_length', 'credit_score',
#        'loan_status'],
#       dtype='object')

# %%
dataset[numerical_features] = dataset[numerical_features].fillna(dataset[numerical_features].mean())
# fillna means missing values(NaN)

# %%
dataset.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_annual_income              0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# person_cred_hist_length           0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
# In scikit-learn, the class SimpleImputer is used to handle missing values in datasets. It provides 


imp = SimpleImputer(strategy= "most_frequent")

# %%
dataset[categorical_features] = imp.fit_transform(dataset[categorical_features])

# %%
dataset.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_annual_income              0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# person_cred_hist_length           0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
classes_count = dataset["loan_status"].value_counts()

plt.pie(classes_count, labels=["No", "Yes"], autopct="%1.1f%%")
plt.title("Is Loan approved or not?")
# Out:
# Text(0.5, 1.0, 'Is Loan approved or not?')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
gender_cnt = dataset["person_gender"].value_counts()
ax = sns.barplot(gender_cnt)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '24841'), Text(0, 0, '20159')]

# %%
edu_cnt = dataset["person_education"].value_counts()
ax = sns.barplot(edu_cnt)
ax.bar_label(ax.containers[0])

# ax means Axes
# Out:
# [Text(0, 0, '13399'),
#  Text(0, 0, '12028'),
#  Text(0, 0, '11972'),
#  Text(0, 0, '6980'),
#  Text(0, 0, '621')]

# %%
#analyze income

sns.histplot(
    data = dataset,
    x = 'person_annual_income',
    bins = 50,
    log_scale=True   
)
# Out:
# <Axes: xlabel='person_annual_income', ylabel='Count'>

# %%
dataset['person_annual_income'].describe()
# Out:
# count    4.500000e+04
# mean     6.827120e+05
# std      6.835912e+05
# min      6.800000e+04
# 25%      4.012340e+05
# 50%      5.699080e+05
# 75%      8.142086e+05
# max      6.120651e+07
# Name: person_annual_income, dtype: float64

# %%
# outliers - box plots

sns.boxplot(
    data=dataset,
    x="loan_status",
    y="person_annual_income"
)
# Out:
# <Axes: xlabel='loan_status', ylabel='person_annual_income'>

# %%
# Credit Score with Loan Approved
sns.histplot(
    data=dataset,
    x="credit_score",
    hue="loan_status",
    bins=20,
    multiple="dodge"
)

# hue is a parameter that adds a third dimension of information to a plot by using color to represent categories.
# Out:
# <Axes: xlabel='credit_score', ylabel='Count'>

# %%
sns.histplot(
    data=dataset,
    x="person_annual_income",
    hue="loan_status",
    bins=20,
    multiple="dodge",
    log_scale=True
)

# a log scale (short for logarithmic scale) means that the axis values are scaled according to the logarithm of the data rather than the raw values.
# Out:
# <Axes: xlabel='person_annual_income', ylabel='Count'>

# %%
dataset['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23443
# MORTGAGE    18489
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
dataset['person_home_ownership'] = dataset['person_home_ownership'].map({"RENT": 1,
"MORTGAGE":2,
"OWN" : 3,
"OTHER" :4})

# %%
dataset['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
dataset['loan_intent'] = dataset['loan_intent'] .map({"EDUCATION" : 1,
"MEDICAL" : 2,         
"VENTURE" : 3,          
"PERSONAL" : 4,         
"DEBTCONSOLIDATION" : 5,
"HOMEIMPROVEMENT" : 6 })

# %%
dataset['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# Yes    22858
# No     22142
# Name: count, dtype: int64

# %%
dataset['previous_loan_defaults_on_file'] = dataset['previous_loan_defaults_on_file'].map({"Yes": 1, "No":0})

# %%
dataset['person_gender'].value_counts()
# Out:
# person_gender
# male      24841
# female    20159
# Name: count, dtype: int64

# %%
dataset['person_gender'] = dataset['person_gender'].map({"male": 1, "female":0})

# %%
dataset['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
dataset['person_education'] = dataset['person_education'].map({"Bachelor" : 1,
"Associate" : 2,
"High School" : 3,
"Master" : 4,
"Doctorate" : 5})

# %%
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# le = LabelEncoder()
# dataset["person_home_ownership"] = le.fit_transform(dataset["person_home_ownership"])

# It will encode from 0

# %%
dataset.head()
# Out:
#    person_age  person_gender  person_education  person_annual_income  \
# 0          22              0                 4              611558.0
# 1          21              0                 3              104397.0
# 2          25              0                 3              105723.0
# 3          23              0                 1              677900.5
# 4          24              1                 4              562147.5
#
#    person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               0                      1     385000            4
# 1               0                      3      11000            1
# 2               3                      2      60500            2
# 3               0                      1     385000            2
# 4               1                      1     385000            2
#
#    loan_int_rate  person_cred_hist_length  credit_score  \
# 0          16.02                        3           561
# 1          11.14                        2           504
# 2          12.87                        3           635
# 3          15.23                        2           675
# 4          14.27                        4           586
#
#    previous_loan_defaults_on_file  loan_status
# 0                               0            1
# 1                               1            0
# 2                               0            1
# 3                               0            1
# 4                               0            1

# %% [markdown]
# # correlation heatmap

# %%
num_cols = dataset.select_dtypes(include="number")
corr_matrix = num_cols.corr()

plt.figure(figsize=(15, 8))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

# corr-corrilation
# annot-annotations
# fmt-formatting of text or numbers.
# cmap-colormap
# Out:
# <Axes: >

# %%
num_cols.corr()["loan_status"].sort_values(ascending=False)
# Out:
# loan_status                       1.000000
# loan_int_rate                     0.332005
# loan_amnt                         0.107714
# loan_intent                       0.066898
# person_gender                    -0.000561
# person_education                 -0.003996
# credit_score                     -0.007647
# person_cred_hist_length          -0.014851
# person_emp_exp                   -0.020481
# person_age                       -0.021476
# person_annual_income             -0.135808
# person_home_ownership            -0.237779
# previous_loan_defaults_on_file   -0.543096
# Name: loan_status, dtype: float64

# %% [markdown]
# # Spliting

# %%
X = dataset.iloc[:,:-1]
Y = dataset.iloc[:,-1]

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
x_test.head()
# Out:
#        person_age  person_gender  person_education  person_annual_income  \
# 37979          32              1                 2              823352.5
# 9911           24              1                 2              483123.0
# 43386          22              0                 4              317033.0
# 13822          23              0                 1              339524.0
# 44810          42              1                 3              577779.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 37979              10                      2      82500            1
# 9911                6                      1      99000            1
# 43386               0                      1      55000            2
# 13822               1                      3      55000            3
# 44810              20                      2     110000            6
#
#        loan_int_rate  person_cred_hist_length  credit_score  \
# 37979           6.04                       10           601
# 9911           11.49                        4           647
# 43386          14.88                        4           711
# 13822          13.99                        3           597
# 44810          15.41                       11           586
#
#        previous_loan_defaults_on_file
# 37979                               0
# 9911                                1
# 43386                               0
# 13822                               1
# 44810                               0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[ 1.03947529, -1.10659687, -1.19808532, ...,  0.81673169,
#         -0.03244403, -1.01415574],
#        [-0.4561859 ,  0.90367145,  0.61926063, ..., -0.47891374,
#          0.52468678,  0.98604185],
#        [ 2.20276733, -1.10659687,  1.52793361, ...,  1.33498986,
#          1.00222747,  0.98604185],
#        ...,
#        [ 0.87329072, -1.10659687, -0.28941234, ...,  0.81673169,
#          0.38540408,  0.98604185],
#        [-0.29000132,  0.90367145,  1.52793361, ..., -0.73804283,
#         -0.5696773 , -1.01415574],
#        [-0.29000132, -1.10659687,  0.61926063, ..., -0.73804283,
#          0.62417442,  0.98604185]], shape=(36000, 12))

# %%
# Logistic regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

log_model = LogisticRegression()
log_model.fit(x_train_scaled, y_train)

y_pred = log_model.predict(x_test_scaled)

# Evaluation
print("Logistic Regression Model")
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("CM: ", confusion_matrix(y_test, y_pred))
# Out:
# Logistic Regression Model
# Precision:  0.7411167512690355
# Recall:  0.7263681592039801
# F1 score:  0.7336683417085427
# Accuracy:  0.8822222222222222
# CM:  [[6480  510]
#  [ 550 1460]]

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train_scaled, y_train)

y_pred = knn_model.predict(x_test_scaled)

# Evaluation
print("KNN Model")
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("CM: ", confusion_matrix(y_test, y_pred))
# Out:
# KNN Model
# Precision:  0.732463295269168
# Recall:  0.6701492537313433
# F1 score:  0.6999220576773187
# Accuracy:  0.8716666666666667
# CM:  [[6498  492]
#  [ 663 1347]]

# %%
# Naive Bayes

from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(x_train_scaled, y_train)

y_pred = nb_model.predict(x_test_scaled)

# Evaluation
print("Naive Bayes Model")
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("CM: ", confusion_matrix(y_test, y_pred))
# Out:
# Naive Bayes Model
# Precision:  0.4587723316536876
# Recall:  0.9965174129353234
# F1 score:  0.6282936010037641
# Accuracy:  0.7366666666666667
# CM:  [[4627 2363]
#  [   7 2003]]

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
rfc.fit(x_train_scaled,y_train)

y_pred = rfc.predict(x_test_scaled)

# Evaluation
print("Random Forest Classifier Model")
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("CM: ", confusion_matrix(y_test, y_pred))
# Out:
# Random Forest Classifier Model
# Precision:  0.8679141441937259
# Recall:  0.7845771144278607
# F1 score:  0.8241442383067678
# Accuracy:  0.9252222222222222
# CM:  [[6750  240]
#  [ 433 1577]]

# %%
param_grid_rf = {'n_estimators': [10,20],
                 'max_features': [None, 'sqrt', 'log2'],
                 'max_depth': [None, 5, 6],
                 'criterion': ['gini', 'entropy'],
                 'min_samples_split': [2, 5],
                 'min_samples_leaf': [1, 2, 4]}

grid=GridSearchCV(rfc,param_grid_rf,refit=True,n_jobs=-1)
grid.fit(x_train_scaled, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 6],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [10, 20]})

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 20}

# %%
y_pred = grid.predict(x_test_scaled)

# Evaluation
print("After Hyper Parameter Tuning : ")
print("Precision: ", precision_score(y_test, y_pred))
print("Recall: ", recall_score(y_test, y_pred))
print("F1 score: ", f1_score(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test, y_pred))
print("CM: ", confusion_matrix(y_test, y_pred))
# Out:
# After Hyper Parameter Tuning :
# Precision:  0.8670005564830273
# Recall:  0.7751243781094528
# F1 score:  0.8184922511163646
# Accuracy:  0.9232222222222223
# CM:  [[6751  239]
#  [ 452 1558]]

# %%
categorical_features = [
    'person_gender', 'person_education', 'person_home_ownership', 
    'loan_intent', 'previous_loan_defaults_on_file'
]

numerical_features = [
    'person_age', 'person_annual_income', 'person_emp_exp', 'loan_amnt', 
    'loan_int_rate',  'person_cred_hist_length', 
    'credit_score'
]

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())  # Important for algorithms like KNN/SVM, good practice generally
])
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore')) 
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

clf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', rfc)
])

param_grid = {
    'classifier__n_estimators': [10, 20],
    'classifier__max_depth': [None, 10, 20],
    'classifier__min_samples_split': [2, 5]
}

grid_search = GridSearchCV(clf_pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

print("Training the pipeline...")
grid_search.fit(x_train, y_train)
# Out:
# Training the pipeline...
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['person_age',
#                                                                           'person_annual_income',
#                                                                           'person_emp_exp',
#                                                                           'loan_amnt',
#                                                                           'loan_int_rate',
#                                                                           'person_cred_hist_length',
#                                                                           'credit_score']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(stra...
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['person_gender',
#                                                                           'person_education',
#                                                                           'person_home_ownership',
#                                                                           'loan_intent',
#                                                                           'previous_loan_defaults_on_file'])])),
#                                        ('classifier',
#                                         RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'classifier__max_depth': [None, 10, 20],
#                          'classifier__min_samples_split': [2, 5],
#                          'classifier__n_estimators': [10, 20]},
#              scoring='accuracy')

# %%
y_pred = grid_search.predict(x_test)

# %%
x_test
# Out:
#        person_age  person_gender  person_education  person_annual_income  \
# 37979          32              1                 2              823352.5
# 9911           24              1                 2              483123.0
# 43386          22              0                 4              317033.0
# 13822          23              0                 1              339524.0
# 44810          42              1                 3              577779.0
# ...           ...            ...               ...                   ...
# 14572          21              1                 1             1132242.5
# 30384          39              1                 3              526056.5
# 36665          24              0                 4              671075.0
# 30569          38              1                 2              315707.0
# 5321           25              0                 3              299336.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 37979              10                      2      82500            1
# 9911                6                      1      99000            1
# 43386               0                      1      55000            2
# 13822               1                      3      55000            3
# 44810              20                      2     110000            6
# ...               ...                    ...        ...          ...
# 14572               0                      2     154000            3
# 30384              17                      1      73975            1
# 36665               1                      1     154000            1
# 30569              16                      1      88000            2
# 5321                0                      1      93500            2
#
#        loan_int_rate  person_cred_hist_length  credit_score  \
# 37979           6.04                       10           601
# 9911           11.49                        4           647
# 43386          14.88                        4           711
# 13822          13.99                        3           597
# 44810          15.41                       11           586
# ...              ...                      ...           ...
# 14572           9.99                        2           654
# 30384          16.45                       11           606
# 36665          11.65                        3           614
# 30569          11.01                       14           695
# 5321           11.14                        3           635
#
#        previous_loan_defaults_on_file
# 37979                               0
# 9911                                1
# 43386                               0
# 13822                               1
# 44810                               0
# ...                               ...
# 14572                               0
# 30384                               1
# 36665                               0
# 30569                               0
# 5321                                0
#
# [9000 rows x 12 columns]

# %%
from sklearn.metrics import classification_report,confusion_matrix
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95      6990
#            1       0.87      0.78      0.82      2010
#
#     accuracy                           0.92      9000
#    macro avg       0.90      0.87      0.89      9000
# weighted avg       0.92      0.92      0.92      9000
#
# Confusion Matrix:
# [[6747  243]
#  [ 434 1576]]

# %% [markdown]
# # Random Forest Classifier is having best Precision

# %% [markdown]
# # Pickling

# %%
import pickle

# %%
pickle.dump(grid_search, open("model.pkl", "wb"))

# %%
dataset['loan_amnt'].describe()
# Out:
# count     45000.000000
# mean     105414.733111
# std       69463.753596
# min        5500.000000
# 25%       55000.000000
# 50%       88000.000000
# 75%      134609.750000
# max      385000.000000
# Name: loan_amnt, dtype: float64
